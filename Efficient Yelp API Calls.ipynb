# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#additional imports

import os, json, math, time 

# to make yelpapi
from yelpapi import YelpAPI

# progress bar from tqdm_notebook
from tqdm.notebook import tqdm_notebook

# %%
# !pip install yelpapi
# !pip install tqdm
# Out:
# Requirement already satisfied: yelpapi in c:\users\rosa\anaconda3\envs\dojo-env\lib\site-packages (2.5.0)
# Requirement already satisfied: requests in c:\users\rosa\anaconda3\envs\dojo-env\lib\site-packages (from yelpapi) (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rosa\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rosa\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rosa\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\rosa\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2.0.4)
# Requirement already satisfied: tqdm in c:\users\rosa\anaconda3\envs\dojo-env\lib\site-packages (4.64.1)
# Requirement already satisfied: colorama in c:\users\rosa\anaconda3\envs\dojo-env\lib\site-packages (from tqdm) (0.4.5)

# %% [markdown]
# ## Load credentials and Create Yelp API Object

# %%
# Load API Credentials    
    
with open('/Users/ROSA/.secret/yelp_api.json', 'r') as f:
    login = json.load(f)

# %%
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
login.items()
# Out:
# dict_items([('client-id', 'AzyqDaAFoaPEVDlGQs1aoQ'), ('api-key', 'B4AL2K-z8VSqDQ78_86vJmMqxIdDojIe7H6hFeDTfsrhUg8fxXk-1b_moXJg5tVs7leCsBw7lztyidGjjV-nryW8Jn03gJzK8EybNXP7Oc-XqAuI5hDsUIdk06H4ZHYx')])

# %%
login['api-key']
# Out:
# 'B4AL2K-z8VSqDQ78_86vJmMqxIdDojIe7H6hFeDTfsrhUg8fxXk-1b_moXJg5tVs7leCsBw7lztyidGjjV-nryW8Jn03gJzK8EybNXP7Oc-XqAuI5hDsUIdk06H4ZHYx'

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI (login['api-key'], timeout_s = 5.0)

# %% [markdown]
# ### Define Search Terms and File Paths

# %%
# set our API call parameters and filename before the first call
location = 'San Antonio, TX, 78216'
term = 'boba tea'

# %%
location.split(',')[0]
# Out:
# 'San Antonio'

# %%
## Specify fodler for saving data
FOLDER = 'Data/'

os.makedirs(FOLDER, exist_ok = True)


# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
JSON_FILE
# Out:
# 'Data/San Antonio-boba tea.json'

# %% [markdown]
# ### Load JSON FIle and account for previous results

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:    
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len (folder) > 0:
        # create the folder
        os.makedirs(folder, exist_ok = True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open (JSON_FILE, 'w') as f:
        json.dump([],f)
        
## If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/San Antonio-boba tea.json already exists.

# %%
## Load previous results and use len of results for offset

## set offset based on previous results

# %% [markdown]
# ### Make the first API call to get the first page of data

# %% [markdown]
# - We will use this first result to check:
#     - how many total results there are?
#     - Where is the actual data we want to save?
#     - how many results do we get at a time?

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelp.search_query(term = term, location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 82

# %%
results['businesses']
# Out:
# [{'id': 'cCkVeldKwdH8Tz8AAgX9tA',
#   'alias': 'feng-cha-boba-tea-and-desserts-san-antonio',
#   'name': 'Feng Cha Boba Tea and Desserts',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/V4kz7BG2mTI8wOu6NtQB3g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/feng-cha-boba-tea-and-desserts-san-antonio?adjust_creative=AzyqDaAFoaPEVDlGQs1aoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AzyqDaAFoaPEVDlGQs1aoQ',
#   'review_count': 23,
#   'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#    {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.534712935323807,
#    'longitude': -98.52122847342896},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '8055 West Ave',
#    'address2': 'Ste 100',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78213',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['8055 West Ave', 'Ste 100', 'San Antonio, TX 78213']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 3919.663391072691},
#  {'id': 'etxlgtnLSkeqhyz2g3yVUg',
#   'alias': 'gong-cha-san-antonio-4',
#   'name': 'Gong Cha',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/krbWMRog_eW0buxTBuDSQA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gong-cha-san-antonio-4?adjust_creative=AzyqDaAFoaPEVDlGQs1aoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AzyqDaAFoaPEVDlGQs1aoQ',
#   'review_count': 23,
#   'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.603546, 'longitude': -98.442823},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2903 N Loop 1604 E',
#    'address2': 'Ste 101',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78259',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2903 N Loop 1604 E',
#     'Ste 101',
#     'San Antonio, TX 78259']},
#   'phone': '+12105921011',
#   'display_phone': '(210) 592-1011',
#   'distance': 8321.205236840908},
#  {'id': 'H9vRFCs52gNEoyRx89RDTg',
#   'alias': 't-pioca-san-antonio',
#   'name': 'T-Pioca',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/axy88zcLflQAUO8fJwHcTg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/t-pioca-san-antonio?adjust_creative=AzyqDaAFoaPEVDlGQs1aoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AzyqDaAFoaPEVDlGQs1aoQ',
#   'review_count': 84,
#   'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.531959, 'longitude': -98.484352},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '10100 Reunion Pl',
#    'address2': 'Ste 140',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78216',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['10100 Reunion Pl',
#     'Ste 140',
#     'San Antonio, TX 78216']},
#   'phone': '+12068227163',
#   'display_phone': '(206) 822-7163',
#   'distance': 609.4632154261536},
#  {'id': 'OKK9DHGOTHBw5Uob_1YmcQ',
#   'alias': 'y-bubble-san-antonio-7',
#   'name': 'Y Bubble',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sWmW5BRBaPPtEyWMVrU7nA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/y-bubble-san-antonio-7?adjust_creative=AzyqDaAFoaPEVDlGQs1aoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AzyqDaAFoaPEVDlGQs1aoQ',
#   'review_count': 41,
#   'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#    {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.599058, 'longitude': -98.417534},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '17306 Bulverde Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78259',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['17306 Bulverde Rd', 'San Antonio, TX 78259']},
#   'phone': '+12103325182',
#   'display_phone': '(210) 332-5182',
#   'distance': 9270.310669157152},
#  {'id': 'K6AQLCseRMjJwM1wHvYL1g',
#   'alias': 'kokee-tea-san-antonio',
#   'name': 'Kokee Tea',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5eIGEJ3UgC3ajUJtKyOz_Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kokee-tea-san-antonio?adjust_creative=AzyqDaAFoaPEVDlGQs1aoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AzyqDaAFoaPEVDlGQs1aoQ',
#   'review_count': 28,
#   'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 29.51838, 'longitude': -98.49789},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '7400 San Pedro Ave',
#    'address2': 'Kiosk 6510',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78216',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['7400 San Pedro Ave',
#     'Kiosk 6510',
#     'San Antonio, TX 78216']},
#   'phone': '+18055512903',
#   'display_phone': '(805) 551-2903',
#   'distance': 2606.361855044096},
#  {'id': 'frRZnVjfD_u4_nMsymb9aw',
#   'alias': 'premium-matcha-cafe-maiko-san-antonio',
#   'name': 'Premium Matcha Cafe Maiko',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-0EX46pWZsaK_u5GIG763w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/premium-matcha-cafe-maiko-san-antonio?adjust_creative=AzyqDaAFoaPEVDlGQs1aoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AzyqDaAFoaPEVDlGQs1aoQ',
#   'review_count': 174,
#   'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.522676, 'longitude': -98.506518},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '7115 Blanco Rd',
#    'address2': 'Ste 112',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78216',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['7115 Blanco Rd', 'Ste 112', 'San Antonio, TX 78216']},
#   'phone': '+12102671020',
#   'display_phone': '(210) 267-1020',
#   'distance': 2920.027100141572},
#  {'id': 'R4iAk9sxqlxUl0S9Ae4ilw',
#   'alias': 'the-nest-boba-castle-hills',
#   'name': 'The Nest Boba',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DVUdG3XA0LH66OGmRfNEjw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-nest-boba-castle-hills?adjust_creative=AzyqDaAFoaPEVDlGQs1aoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AzyqDaAFoaPEVDlGQs1aoQ',
#   'review_count': 59,
#   'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.51859, 'longitude': -98.5078},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '6903 Blanco Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'Castle Hills',
#    'zip_code': '78213',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['6903 Blanco Rd', 'Castle Hills, TX 78213']},
#   'phone': '+12104449596',
#   'display_phone': '(210) 444-9596',
#   'distance': 3276.2421862455944},
#  {'id': 'dF9K2A375cKe2cjiWirWsA',
#   'alias': 'kung-fu-tea-san-antonio-5',
#   'name': 'Kung Fu Tea',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DGlLZ2xvKxOqV5306KW9ig/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kung-fu-tea-san-antonio-5?adjust_creative=AzyqDaAFoaPEVDlGQs1aoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AzyqDaAFoaPEVDlGQs1aoQ',
#   'review_count': 13,
#   'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.605787, 'longitude': -98.467322},
#   'transactions': [],
#   'location': {'address1': '18130 San Pedro Ave Suite 108',
#    'address2': None,
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78232',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['18130 San Pedro Ave Suite 108',
#     'San Antonio, TX 78232']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 7818.321895764529},
#  {'id': '-3ZYeM_1GKyVlyol49HTxQ',
#   'alias': 'lustea-san-antonio',
#   'name': 'Lustea',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2H-fWot0wdf6LktmPsGLVg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lustea-san-antonio?adjust_creative=AzyqDaAFoaPEVDlGQs1aoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AzyqDaAFoaPEVDlGQs1aoQ',
#   'review_count': 78,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 29.519258402741237,
#    'longitude': -98.50303003185626},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '602 NW Loop 410',
#    'address2': 'Ste 130',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78216',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['602 NW Loop 410', 'Ste 130', 'San Antonio, TX 78216']},
#   'phone': '+12105980089',
#   'display_phone': '(210) 598-0089',
#   'distance': 2875.719568805168},
#  {'id': 'GbRL6LrBAJgaOUZh78GrlA',
#   'alias': 'sp-café-san-antonio',
#   'name': 'SP Café',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1-9Tfai4OQGHQasd6beNpw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sp-caf%C3%A9-san-antonio?adjust_creative=AzyqDaAFoaPEVDlGQs1aoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AzyqDaAFoaPEVDlGQs1aoQ',
#   'review_count': 317,
#   'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#    {'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.51915204792389,
#    'longitude': -98.50330176552696},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '602 NW Loop 410',
#    'address2': 'Ste 126',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78216',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['602 NW Loop 410', 'Ste 126', 'San Antonio, TX 78216']},
#   'phone': '+12105419689',
#   'display_phone': '(210) 541-9689',
#   'distance': 2903.26453482143},
#  {'id': 'fnXIHXH7rmefbFKRKZnD9Q',
#   'alias': 'y-bubble-san-antonio-6',
#   'name': 'Y Bubble',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1sYnxl2A964uWQLBYmZiVQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/y-bubble-san-antonio-6?adjust_creative=AzyqDaAFoaPEVDlGQs1aoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AzyqDaAFoaPEVDlGQs1aoQ',
#   'review_count': 84,
#   'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#    {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.62513902118377,
#    'longitude': -98.49642197956682},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '19141 Stone Oak Pkwy',
#    'address2': 'Ste 501',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78258',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['19141 Stone Oak Pkwy',
#     'Ste 501',
#     'San Antonio, TX 78258']},
#   'phone': '+12103385551',
#   'display_phone': '(210) 338-5551',
#   'distance': 9984.57802106248},
#  {'id': 'TUPyDL9C3p7OEqsVdjIm6g',
#   'alias': 'bc-bubble-tea-san-antonio-2',
#   'name': 'BC Bubble Tea',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DJ7Rrlt9BTMqOR9WcRyCtw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bc-bubble-tea-san-antonio-2?adjust_creative=AzyqDaAFoaPEVDlGQs1aoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AzyqDaAFoaPEVDlGQs1aoQ',
#   'review_count': 21,
#   'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#    {'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.51069620389994,
#    'longitude': -98.39433264345556},
#   'transactions': [],
#   'location': {'address1': '4905 Walzem Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78218',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['4905 Walzem Rd', 'San Antonio, TX 78218']},
#   'phone': '+12102760919',
#   'display_phone': '(210) 276-0919',
#   'distance': 8836.680267002828},
#  {'id': 'h2AaBZ2KEDEPiJNmHyvVyg',
#   'alias': 'artea-san-antonio',
#   'name': 'Artea',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DddiEpvvFEfNTNaY2w-Zxg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/artea-san-antonio?adjust_creative=AzyqDaAFoaPEVDlGQs1aoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AzyqDaAFoaPEVDlGQs1aoQ',
#   'review_count': 438,
#   'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#    {'alias': 'taiwanese', 'title': 'Taiwanese'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.5626508049732,
#    'longitude': -98.6118145969732},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '6362 De Zavala Rd',
#    'address2': 'Ste 108',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78249',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['6362 De Zavala Rd',
#     'Ste 108',
#     'San Antonio, TX 78249']},
#   'phone': '+12104621388',
#   'display_phone': '(210) 462-1388',
#   'distance': 13009.347113333286},
#  {'id': 'BaawjkZnTJA9KvRIwIpaRg',
#   'alias': 'tealicious-cafe-san-antonio-7',
#   'name': 'Tealicious Cafe',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/a88j8hHgndbsQ0Dx7R20qA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tealicious-cafe-san-antonio-7?adjust_creative=AzyqDaAFoaPEVDlGQs1aoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AzyqDaAFoaPEVDlGQs1aoQ',
#   'review_count': 25,
#   'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#    {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 29.60670904076319,
#    'longitude': -98.51219495395918},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1160 N Loop 1604 W',
#    'address2': None,
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78248',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1160 N Loop 1604 W', 'San Antonio, TX 78248']},
#   'phone': '+12109997989',
#   'display_phone': '(210) 999-7989',
#   'distance': 8389.916472067927},
#  {'id': 'UfdmGz4Bbv6fRSwWA4mi7A',
#   'alias': 'san-poke-san-antonio-3',
#   'name': 'San Poke',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XVC2pcamj7ig2IzSAqFGGg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/san-poke-san-antonio-3?adjust_creative=AzyqDaAFoaPEVDlGQs1aoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AzyqDaAFoaPEVDlGQs1aoQ',
#   'review_count': 201,
#   'categories': [{'alias': 'poke', 'title': 'Poke'},
#    {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.635699, 'longitude': -98.454254},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '20770 US Hwy 281 N',
#    'address2': 'Ste 105',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78258',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['20770 US Hwy 281 N',
#     'Ste 105',
#     'San Antonio, TX 78258']},
#   'phone': '+12109982556',
#   'display_phone': '(210) 998-2556',
#   'distance': 11336.735798256377},
#  {'id': '9brvj3UTxzJKcneDhxg2bg',
#   'alias': 'kung-fu-tea-san-antonio-2',
#   'name': 'Kung Fu Tea',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/v55hLBoiVIw5J6X1IcNHGg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kung-fu-tea-san-antonio-2?adjust_creative=AzyqDaAFoaPEVDlGQs1aoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AzyqDaAFoaPEVDlGQs1aoQ',
#   'review_count': 99,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#    {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.47556783504158,
#    'longitude': -98.46325047605814},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '5231 Broadway',
#    'address2': 'Ste 101',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78209',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['5231 Broadway', 'Ste 101', 'San Antonio, TX 78209']},
#   'phone': '+12104550092',
#   'display_phone': '(210) 455-0092',
#   'distance': 6971.541038380827},
#  {'id': 'ZD32AMiUV2yczk9-JRBAaQ',
#   'alias': 'tea-time-san-antonio-2',
#   'name': 'Tea Time',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CINR_TxqKXf_31C9d2AqKg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tea-time-san-antonio-2?adjust_creative=AzyqDaAFoaPEVDlGQs1aoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AzyqDaAFoaPEVDlGQs1aoQ',
#   'review_count': 112,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.5469861507603,
#    'longitude': -98.5778496257603},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '11255 Huebner Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78230',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['11255 Huebner Rd', 'San Antonio, TX 78230']},
#   'phone': '+12104685088',
#   'display_phone': '(210) 468-5088',
#   'distance': 9466.185027020492},
#  {'id': 'LiEGdDo2gzzE8QaujncjTA',
#   'alias': 'boba-tea-san-antonio',
#   'name': 'Boba Tea',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EsWQ4LDZ9mfv9du7lYUFtQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/boba-tea-san-antonio?adjust_creative=AzyqDaAFoaPEVDlGQs1aoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AzyqDaAFoaPEVDlGQs1aoQ',
#   'review_count': 140,
#   'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.3804514234602,
#    'longitude': -98.4587749141726},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '3850 S New Braunfels Ave',
#    'address2': 'Ste 108',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78223',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3850 S New Braunfels Ave',
#     'Ste 108',
#     'San Antonio, TX 78223']},
#   'phone': '+12105322999',
#   'display_phone': '(210) 532-2999',
#   'distance': 17469.117661687138},
#  {'id': 'WUjpw4nxzx3Kgh8Fu3ASQw',
#   'alias': 'boba-tea-lounge-selma-2',
#   'name': 'Boba Tea Lounge',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XI6AH36Nq68I2TJEtdL11g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/boba-tea-lounge-selma-2?adjust_creative=AzyqDaAFoaPEVDlGQs1aoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AzyqDaAFoaPEVDlGQs1aoQ',
#   'review_count': 195,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#    {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.5758046634408,
#    'longitude': -98.3252928742823},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '15069 Interstate 35 Frontage Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Selma',
#    'zip_code': '78154',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['15069 Interstate 35 Frontage Rd', 'Selma, TX 78154']},
#   'phone': '+12103756107',
#   'display_phone': '(210) 375-6107',
#   'distance': 15663.309563784464},
#  {'id': 'kGdNXXxF6vdd1X7WHGzgqg',
#   'alias': 'mochinut-san-antonio',
#   'name': 'Mochinut',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LxvrWbt-3idY1H3wc2polg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mochinut-san-antonio?adjust_creative=AzyqDaAFoaPEVDlGQs1aoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AzyqDaAFoaPEVDlGQs1aoQ',
#   'review_count': 134,
#   'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#    {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 29.56402, 'longitude': -98.58681},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '5222 De Zavala Rd',
#    'address2': 'Ste 328',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78249',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['5222 De Zavala Rd',
#     'Ste 328',
#     'San Antonio, TX 78249']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 10677.52198613214}]

# %%
## How many results total?
pd.DataFrame(results['businesses'])
# Out:
#                         id                                       alias  \
# 0   cCkVeldKwdH8Tz8AAgX9tA  feng-cha-boba-tea-and-desserts-san-antonio
# 1   etxlgtnLSkeqhyz2g3yVUg                      gong-cha-san-antonio-4
# 2   H9vRFCs52gNEoyRx89RDTg                         t-pioca-san-antonio
# 3   OKK9DHGOTHBw5Uob_1YmcQ                      y-bubble-san-antonio-7
# 4   K6AQLCseRMjJwM1wHvYL1g                       kokee-tea-san-antonio
# 5   frRZnVjfD_u4_nMsymb9aw       premium-matcha-cafe-maiko-san-antonio
# 6   R4iAk9sxqlxUl0S9Ae4ilw                  the-nest-boba-castle-hills
# 7   dF9K2A375cKe2cjiWirWsA                   kung-fu-tea-san-antonio-5
# 8   -3ZYeM_1GKyVlyol49HTxQ                          lustea-san-antonio
# 9   GbRL6LrBAJgaOUZh78GrlA                         sp-café-san-antonio
# 10  fnXIHXH7rmefbFKRKZnD9Q                      y-bubble-san-antonio-6
# 11  TUPyDL9C3p7OEqsVdjIm6g                 bc-bubble-tea-san-antonio-2
# 12  h2AaBZ2KEDEPiJNmHyvVyg                           artea-san-antonio
# 13  BaawjkZnTJA9KvRIwIpaRg               tealicious-cafe-san-antonio-7
# 14  UfdmGz4Bbv6fRSwWA4mi7A                      san-poke-san-antonio-3
# 15  9brvj3UTxzJKcneDhxg2bg                   kung-fu-tea-san-antonio-2
# 16  ZD32AMiUV2yczk9-JRBAaQ                      tea-time-san-antonio-2
# 17  LiEGdDo2gzzE8QaujncjTA                        boba-tea-san-antonio
# 18  WUjpw4nxzx3Kgh8Fu3ASQw                     boba-tea-lounge-selma-2
# 19  kGdNXXxF6vdd1X7WHGzgqg                        mochinut-san-antonio
#
#                               name  \
# 0   Feng Cha Boba Tea and Desserts
# 1                         Gong Cha
# 2                          T-Pioca
# 3                         Y Bubble
# 4                        Kokee Tea
# 5        Premium Matcha Cafe Maiko
# 6                    The Nest Boba
# 7                      Kung Fu Tea
# 8                           Lustea
# 9                          SP Café
# 10                        Y Bubble
# 11                   BC Bubble Tea
# 12                           Artea
# 13                 Tealicious Cafe
# 14                        San Poke
# 15                     Kung Fu Tea
# 16                        Tea Time
# 17                        Boba Tea
# 18                 Boba Tea Lounge
# 19                        Mochinut
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/V4kz7B...      False
# 1   https://s3-media3.fl.yelpcdn.com/bphoto/krbWMR...      False
# 2   https://s3-media4.fl.yelpcdn.com/bphoto/axy88z...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/sWmW5B...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/5eIGEJ...      False
# 5   https://s3-media2.fl.yelpcdn.com/bphoto/-0EX46...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/DVUdG3...      False
# 7   https://s3-media2.fl.yelpcdn.com/bphoto/DGlLZ2...      False
# 8   https://s3-media4.fl.yelpcdn.com/bphoto/2H-fWo...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/1-9Tfa...      False
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/1sYnxl...      False
# 11  https://s3-media1.fl.yelpcdn.com/bphoto/DJ7Rrl...      False
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/DddiEp...      False
# 13  https://s3-media3.fl.yelpcdn.com/bphoto/a88j8h...      False
# 14  https://s3-media2.fl.yelpcdn.com/bphoto/XVC2pc...      False
# 15  https://s3-media1.fl.yelpcdn.com/bphoto/v55hLB...      False
# 16  https://s3-media4.fl.yelpcdn.com/bphoto/CINR_T...      False
# 17  https://s3-media1.fl.yelpcdn.com/bphoto/EsWQ4L...      False
# 18  https://s3-media1.fl.yelpcdn.com/bphoto/XI6AH3...      False
# 19  https://s3-media3.fl.yelpcdn.com/bphoto/LxvrWb...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/feng-cha-boba-tea-and...            23
# 1   https://www.yelp.com/biz/gong-cha-san-antonio-...            23
# 2   https://www.yelp.com/biz/t-pioca-san-antonio?a...            84
# 3   https://www.yelp.com/biz/y-bubble-san-antonio-...            41
# 4   https://www.yelp.com/biz/kokee-tea-san-antonio...            28
# 5   https://www.yelp.com/biz/premium-matcha-cafe-m...           174
# 6   https://www.yelp.com/biz/the-nest-boba-castle-...            59
# 7   https://www.yelp.com/biz/kung-fu-tea-san-anton...            13
# 8   https://www.yelp.com/biz/lustea-san-antonio?ad...            78
# 9   https://www.yelp.com/biz/sp-caf%C3%A9-san-anto...           317
# 10  https://www.yelp.com/biz/y-bubble-san-antonio-...            84
# 11  https://www.yelp.com/biz/bc-bubble-tea-san-ant...            21
# 12  https://www.yelp.com/biz/artea-san-antonio?adj...           438
# 13  https://www.yelp.com/biz/tealicious-cafe-san-a...            25
# 14  https://www.yelp.com/biz/san-poke-san-antonio-...           201
# 15  https://www.yelp.com/biz/kung-fu-tea-san-anton...            99
# 16  https://www.yelp.com/biz/tea-time-san-antonio-...           112
# 17  https://www.yelp.com/biz/boba-tea-san-antonio?...           140
# 18  https://www.yelp.com/biz/boba-tea-lounge-selma...           195
# 19  https://www.yelp.com/biz/mochinut-san-antonio?...           134
#
#                                            categories  rating  \
# 0   [{'alias': 'desserts', 'title': 'Desserts'}, {...     4.5
# 1     [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 2   [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.5
# 3   [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.5
# 4     [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     3.5
# 5   [{'alias': 'icecream', 'title': 'Ice Cream & F...     4.5
# 6   [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     4.0
# 7   [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.5
# 8   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     3.5
# 9   [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.0
# 10  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.5
# 11  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.5
# 12  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.5
# 13  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     5.0
# 14  [{'alias': 'poke', 'title': 'Poke'}, {'alias':...     4.5
# 15  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0
# 16  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 17  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.0
# 18  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0
# 19  [{'alias': 'donuts', 'title': 'Donuts'}, {'ali...     3.5
#
#                                           coordinates        transactions  \
# 0   {'latitude': 29.534712935323807, 'longitude': ...                  []
# 1    {'latitude': 29.603546, 'longitude': -98.442823}                  []
# 2    {'latitude': 29.531959, 'longitude': -98.484352}  [delivery, pickup]
# 3    {'latitude': 29.599058, 'longitude': -98.417534}                  []
# 4      {'latitude': 29.51838, 'longitude': -98.49789}  [delivery, pickup]
# 5    {'latitude': 29.522676, 'longitude': -98.506518}  [delivery, pickup]
# 6       {'latitude': 29.51859, 'longitude': -98.5078}  [delivery, pickup]
# 7    {'latitude': 29.605787, 'longitude': -98.467322}                  []
# 8   {'latitude': 29.519258402741237, 'longitude': ...          [delivery]
# 9   {'latitude': 29.51915204792389, 'longitude': -...          [delivery]
# 10  {'latitude': 29.62513902118377, 'longitude': -...                  []
# 11  {'latitude': 29.51069620389994, 'longitude': -...                  []
# 12  {'latitude': 29.5626508049732, 'longitude': -9...  [delivery, pickup]
# 13  {'latitude': 29.60670904076319, 'longitude': -...                  []
# 14   {'latitude': 29.635699, 'longitude': -98.454254}          [delivery]
# 15  {'latitude': 29.47556783504158, 'longitude': -...  [delivery, pickup]
# 16  {'latitude': 29.5469861507603, 'longitude': -9...                  []
# 17  {'latitude': 29.3804514234602, 'longitude': -9...          [delivery]
# 18  {'latitude': 29.5758046634408, 'longitude': -9...          [delivery]
# 19     {'latitude': 29.56402, 'longitude': -98.58681}            [pickup]
#
#    price                                           location         phone  \
# 0     $$  {'address1': '8055 West Ave', 'address2': 'Ste...
# 1     $$  {'address1': '2903 N Loop 1604 E', 'address2':...  +12105921011
# 2      $  {'address1': '10100 Reunion Pl', 'address2': '...  +12068227163
# 3     $$  {'address1': '17306 Bulverde Rd', 'address2': ...  +12103325182
# 4    NaN  {'address1': '7400 San Pedro Ave', 'address2':...  +18055512903
# 5      $  {'address1': '7115 Blanco Rd', 'address2': 'St...  +12102671020
# 6      $  {'address1': '6903 Blanco Rd', 'address2': Non...  +12104449596
# 7    NaN  {'address1': '18130 San Pedro Ave Suite 108', ...
# 8     $$  {'address1': '602 NW Loop 410', 'address2': 'S...  +12105980089
# 9     $$  {'address1': '602 NW Loop 410', 'address2': 'S...  +12105419689
# 10    $$  {'address1': '19141 Stone Oak Pkwy', 'address2...  +12103385551
# 11   NaN  {'address1': '4905 Walzem Rd', 'address2': '',...  +12102760919
# 12    $$  {'address1': '6362 De Zavala Rd', 'address2': ...  +12104621388
# 13    $$  {'address1': '1160 N Loop 1604 W', 'address2':...  +12109997989
# 14    $$  {'address1': '20770 US Hwy 281 N', 'address2':...  +12109982556
# 15    $$  {'address1': '5231 Broadway', 'address2': 'Ste...  +12104550092
# 16    $$  {'address1': '11255 Huebner Rd', 'address2': '...  +12104685088
# 17    $$  {'address1': '3850 S New Braunfels Ave', 'addr...  +12105322999
# 18     $  {'address1': '15069 Interstate 35 Frontage Rd'...  +12103756107
# 19    $$  {'address1': '5222 De Zavala Rd', 'address2': ...
#
#      display_phone      distance
# 0                    3919.663391
# 1   (210) 592-1011   8321.205237
# 2   (206) 822-7163    609.463215
# 3   (210) 332-5182   9270.310669
# 4   (805) 551-2903   2606.361855
# 5   (210) 267-1020   2920.027100
# 6   (210) 444-9596   3276.242186
# 7                    7818.321896
# 8   (210) 598-0089   2875.719569
# 9   (210) 541-9689   2903.264535
# 10  (210) 338-5551   9984.578021
# 11  (210) 276-0919   8836.680267
# 12  (210) 462-1388  13009.347113
# 13  (210) 999-7989   8389.916472
# 14  (210) 998-2556  11336.735798
# 15  (210) 455-0092   6971.541038
# 16  (210) 468-5088   9466.185027
# 17  (210) 532-2999  17469.117662
# 18  (210) 375-6107  15663.309564
# 19                  10677.521986

# %% [markdown]
# - Where is the actual data we want to save?

# %%
## How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
(results['total'])/results_per_page
# Out:
# 4.1

# %% [markdown]
# - Calculate how many pages of results needed to cover the total_results

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/results_per_page)
n_pages
# Out:
# 5

# %%
for i in tqdm_notebook(range(1,n_pages+1)):
    ## The block of code we want to TRY to run
    try: 
        
        time.sleep(.2)
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        
        ## save number of results for to use as offset
        n_results = len(previous_results)
        
        
        ## use n_results as the OFFSET 
        results = yelp.search_query(location = location, term = term,
                                   offset = n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])
        
        with open (JSON_FILE, 'w') as f:
            json.dump(previous_results, f)

            
    ## What to do if we get an error/exception.
    except Exception as e:
        print('[!] ERROR', e)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %% [markdown]
# ## Open the Final JSON File with Pandas

# %%
df = pd.read_json(JSON_FILE)

# %%
df.head()
# Out:
#                        id                                  alias  \
# 0  etxlgtnLSkeqhyz2g3yVUg                 gong-cha-san-antonio-4
# 1  H9vRFCs52gNEoyRx89RDTg                    t-pioca-san-antonio
# 2  OKK9DHGOTHBw5Uob_1YmcQ                 y-bubble-san-antonio-7
# 3  K6AQLCseRMjJwM1wHvYL1g                  kokee-tea-san-antonio
# 4  frRZnVjfD_u4_nMsymb9aw  premium-matcha-cafe-maiko-san-antonio
#
#                         name  \
# 0                   Gong Cha
# 1                    T-Pioca
# 2                   Y Bubble
# 3                  Kokee Tea
# 4  Premium Matcha Cafe Maiko
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/krbWMR...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/axy88z...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/sWmW5B...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/5eIGEJ...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/-0EX46...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/gong-cha-san-antonio-...            23
# 1  https://www.yelp.com/biz/t-pioca-san-antonio?a...            84
# 2  https://www.yelp.com/biz/y-bubble-san-antonio-...            41
# 3  https://www.yelp.com/biz/kokee-tea-san-antonio...            28
# 4  https://www.yelp.com/biz/premium-matcha-cafe-m...           174
#
#                                           categories  rating  \
# 0    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 1  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.5
# 2  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.5
# 3    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     3.5
# 4  [{'alias': 'icecream', 'title': 'Ice Cream & F...     4.5
#
#                                         coordinates        transactions price  \
# 0  {'latitude': 29.603546, 'longitude': -98.442823}                  []    $$
# 1  {'latitude': 29.531959, 'longitude': -98.484352}  [pickup, delivery]     $
# 2  {'latitude': 29.599058, 'longitude': -98.417534}                  []    $$
# 3    {'latitude': 29.51838, 'longitude': -98.49789}  [pickup, delivery]   NaN
# 4  {'latitude': 29.522676, 'longitude': -98.506518}  [pickup, delivery]     $
#
#                                             location         phone  \
# 0  {'address1': '2903 N Loop 1604 E', 'address2':...  +12105921011
# 1  {'address1': '10100 Reunion Pl', 'address2': '...  +12068227163
# 2  {'address1': '17306 Bulverde Rd', 'address2': ...  +12103325182
# 3  {'address1': '7400 San Pedro Ave', 'address2':...  +18055512903
# 4  {'address1': '7115 Blanco Rd', 'address2': 'St...  +12102671020
#
#     display_phone     distance
# 0  (210) 592-1011  8321.205237
# 1  (206) 822-7163   609.463215
# 2  (210) 332-5182  9270.310669
# 3  (805) 551-2903  2606.361855
# 4  (210) 267-1020  2920.027100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             74 non-null     object
#  1   alias          74 non-null     object
#  2   name           74 non-null     object
#  3   image_url      74 non-null     object
#  4   is_closed      74 non-null     bool
#  5   url            74 non-null     object
#  6   review_count   74 non-null     int64
#  7   categories     74 non-null     object
#  8   rating         74 non-null     float64
#  9   coordinates    74 non-null     object
#  10  transactions   74 non-null     object
#  11  price          51 non-null     object
#  12  location       74 non-null     object
#  13  phone          74 non-null     object
#  14  display_phone  74 non-null     object
#  15  distance       74 non-null     float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 8.9+ KB

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/San Antonio-boba tea.csv.gz'

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file,compression = 'gzip', index = False)
